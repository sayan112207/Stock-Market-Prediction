# %% [markdown]
# <a href="https://colab.research.google.com/github/sayan112207/Stock-Market-Prediction/blob/main/Daily_Monte_Carlo_Simulation_for_Stock_Price_Prediction_Intervals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Monte Carlo Simulation for Empirically Derived Stock Price Prediction Intervals

# %% [markdown]
# ##1. Introduction
#
# Most time-series libraries gives us point predictions and prediction intervals when forecasting. This is of course very useful for making predictions about the future. But what if we want to know the probability that a future value is above some important threshold? An example would be that a stock price in the future is above or below the strike price of an option. That's were pairing Monte Carlo simulation and time series modeling can come in handy.
#
# To perform this analysis, the daily closing price data for Netflix from Yahoo Finance for the past 7 years was collected. Then for the last 500 trading days split into two groups. The first was used to pick a distribution for the predictions and set its parameters. The second was used for validating this approach.

# %%
import datetime
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib as mpl
# %matplotlib inline
mpl.rcParams['figure.figsize'] = (12,8)
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# sets the sample period as 7 years back from 09/12/2019
end = datetime.datetime(2024, 1, 4)
start = end - datetime.timedelta(days = 20*365)


# gets the closing price fo Netflix for the past 5 years
my_stock = yf.Ticker('NFLX')
my_stock = pd.DataFrame(my_stock.history(start = start, end = end)['Close'])
my_stock = my_stock.rename(str.lower, axis = 'columns')

# %%
# grabs the last 100 observations, which will be reduced to 50 for the purpose of fitting a
# distribution for Monte Carlo simulation
my_stock_resid_distr_fitting = my_stock[-500:]
# creates a training subset missing the final 100 observations, which are being withheld
my_stock_train = my_stock[~my_stock.isin(my_stock_resid_distr_fitting).all(1)]
# grabs the final 50 observations for a test set
my_stock_test = my_stock_resid_distr_fitting[-250:]
# reduces the distribution fitting dataset to 50 observations
my_stock_resid_distr_fitting = my_stock_resid_distr_fitting[~my_stock_resid_distr_fitting.isin(my_stock_test).all(1)]

# plots the my_stock weekly closing price over the past 5 years
plt.plot(my_stock.index, my_stock.close)
plt.title('Daily Closing Price: Past 20 Years')
plt.xlabel('Date')
plt.ylabel('Closing Share Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##2. Establishing the Order of Integration
# Before modeling, the order of integration of our time series needs to be established. If it is not stationary, aka I(0), then we will have issues with auto-correlation in our residuals, which violates an essential assumption made by many statistical models (meaning our model would be bad). To determine the order of integration, Auto-Correlation Functions and Augmented-Dickey Fuller Tests can help us out.
#
# Note: stationary is a short way of saying that the mean and variance of the series do not vary over time.

# %% [markdown]
# ### A. Auto-Correlation Function Plots
# The line of the ACF shows strong postive auto-correlation for the first 500, or so, lags. Then there is a long period of negative auto-correlation. This is a good indication that the stock price is non-stationary.

# %%
# to suppress warnings
warnings.filterwarnings('ignore')

# sets the plot size to 12x8
mpl.rcParams['figure.figsize'] = (12,8)

# plots the ACF for the entire train period
pd.plotting.autocorrelation_plot(my_stock_train.close)
plt.show()

# %% [markdown]
# The ACF plot for the differenced stock prices, however, looks stationary. This suggests the stock price is I(1)

# %%
# to suppress warnings
warnings.filterwarnings('ignore')

# sets the plot size to 12x8
mpl.rcParams['figure.figsize'] = (12,8)

# plots the ACF for the differenced data over the entire train period
pd.plotting.autocorrelation_plot(my_stock_train.close.diff().dropna())
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# ###B. Augmented Dickey-Fuller Tests
# The ADF tests confirm that the stock price is not stationary, but its first difference is. This means the stock price is integrated to the order 1 and will need to be differenced one time for modeling.

# %%
# to suppress warnings
warnings.filterwarnings('ignore')

# imports the Augmented Dickey-Fuller Test for establishing the order of integration of
# time series
from statsmodels.tsa.stattools import adfuller

# performs ADF tests with no constant, a constant, and a constant plus linear trend on
# NFLX closing share prices
for i in ['n', 'c', 'ct']:
    result = adfuller(my_stock_train.close, regression = i)
    print('ADF Statistic with %s for Closing my_stock price: %f' % (i, result[0]))
    print('p-value: %f' % result[1])
    print('')

# performs ADF tests with no constant, a constant, and a constant plus linear trend on
# differenced NFLX closing share prices
for i in ['n', 'c', 'ct']:
    result = adfuller(my_stock_train.close.diff().dropna(), regression = i)
    print('ADF Statistic with %s for Differenced Closing my_stock price: %f' % (i, result[0]))
    print('p-value: %f' % result[1])
    print('')
# Out:
# ADF Statistic with n for Closing my_stock price: 2.673586
# p-value: 0.999073
#
# ADF Statistic with c for Closing my_stock price: 1.672452
# p-value: 0.998059
#
# ADF Statistic with ct for Closing my_stock price: -0.619168
# p-value: 0.977951
#
# ADF Statistic with n for Differenced Closing my_stock price: -11.196976
# p-value: 0.000000
#
# ADF Statistic with c for Differenced Closing my_stock price: -11.378223
# p-value: 0.000000
#
# ADF Statistic with ct for Differenced Closing my_stock price: -11.573137
# p-value: 0.000000

# %% [markdown]
# ## 3. Estimating a Simple ARIMA Model
# Here we estimated a simple ARIMA model of order (1, 1, 1) on the natural logarithm of the differenced stock prices to control for heteroskedasticity. The residuals on the training data set appear stationary, but somewhere there are some big spikes giving a long tails to the distribution of residuals. As just mentioned, the distribution of residuals have long tails, and the center of the distribution is a sharp peak around zero. Because the mean of the distributions is roughly zero, it seems reasonable to proceed with this simple model. We just need to keep in mind the residuals may be differently distributed than a normal distribution because of the long tails and sharp peak.

# %%
# to suppress warnings
warnings.filterwarnings('ignore')

# imports the ARIMA model
from statsmodels.tsa.arima.model import ARIMA

# fits the ARIMA model
my_stock_arima = ARIMA(np.log(my_stock_train.astype(float)), order = (1, 1, 1))
my_stock_arima_fit = my_stock_arima.fit()
print(my_stock_arima_fit.summary())

# sets the plot size to 12x8
mpl.rcParams['figure.figsize'] = (12,8)

# plot residual errors of the training data
residuals = pd.DataFrame(my_stock_arima_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 4530
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                8944.869
# Date:                Tue, 02 Apr 2024   AIC                         -17883.737
# Time:                        13:41:56   BIC                         -17864.482
# Sample:                             0   HQIC                        -17876.955
#                                - 4530
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2816      0.444     -0.635      0.526      -1.151       0.588
# ma.L1          0.3085      0.442      0.698      0.485      -0.558       1.175
# sigma2         0.0011   5.97e-06    188.899      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            174726.50
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.43   Skew:                            -1.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                        33.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                  0
# count  4530.000000
# mean      0.001378
# std       0.040179
# min      -0.526076
# 25%      -0.013525
# 50%       0.000425
# 75%       0.016013
# max       1.488077

# %% [markdown]
# ## 4. Picking a Distribution for Predictions
# After choosing a simple ARIMA model, we performed a rolling forecast on one of the withheld data sets and examined the residuals. It's roughly bell-shaped and appears to be centered at 0. The fitting function indicates the Laplacian distribution is a reasonable distribution to use for our Monte Carlo simulations. Here is an example of automatically assuming a normal distribution getting us into trouble. Often times a different distribution is a better fit, empirically or theoretically (based on existence of bounds, etc). The Laplacian distribution is often a good fit for stock returns because of its fat tails, but again, always check first.

# %%
# to suppress warnings
warnings.filterwarnings('ignore')

# imports the mean squared error function
from sklearn.metrics import mean_squared_error

# from https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/

# creates a new dataframe that will be added to as the forecast rolls
history = np.log(my_stock_train.astype(float))
# creates an empty list that will hold predictions
predictions = []
# loops through the indexes of the set being forecased
for i in range(len(my_stock_resid_distr_fitting)):
    # estimates an ARIMA model of order (1,1,1)
    model = ARIMA(history, order = (1,1,1))
    # fits the model
    model_fit = model.fit()
    # forecasts the next period
    output = model_fit.forecast()
    # takes the predicted value and saves it in yhat
    yhat = np.e ** output[output.index[0]]
    # appends yhat to the list of predictions
    predictions.append(yhat)
    # grabs the observation at the ith index
    obs = my_stock_resid_distr_fitting[i : i + 1]
    # appends the observation to the estimation data set
    history = history.append(np.log(obs.astype(float)))

# prints the MSE of the model for the rolling forecast period
error = mean_squared_error(my_stock_resid_distr_fitting, predictions)
print('Test MSE: %.3f' % error)

# converts the predictions list to a pandas dataframe with the same index as the actual values
# for plotting purposes
predictions = pd.DataFrame(predictions)
predictions.index = my_stock_resid_distr_fitting.index

# sets the plot size to 12x8
mpl.rcParams['figure.figsize'] = (12,8)

# plots the predicted and actual stock prices
plt.plot(my_stock_resid_distr_fitting)
plt.plot(predictions, color = 'red')
plt.xlabel('Date')
plt.ylabel('Dollars')
plt.title('Predicted vs. Actual Closing Weekly Stock Price')
plt.legend(['my_stock_resid_distr_fitting', 'predictions'])
plt.show()
# Out:
# Test MSE: 205.474

# %%
# to suppress warnings
warnings.filterwarnings('ignore')

# sets the plot size to 12x8
mpl.rcParams['figure.figsize'] = (12,8)

# plots the residuals
tune_residuals = my_stock_resid_distr_fitting.close - predictions[0]
tune_residuals.plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# to suppress warnings
warnings.filterwarnings('ignore')

# produces a summary of the residuals
tune_residuals.astype(float).describe()
# Out:
# count    250.000000
# mean      -1.015347
# std       14.327039
# min     -122.745185
# 25%       -6.740744
# 50%       -1.502195
# 75%        5.417317
# max       43.066071
# dtype: float64

# %%
# !pip install fitter
# Out:
# Requirement already satisfied: fitter in /usr/local/lib/python3.10/dist-packages (1.7.0)
# Requirement already satisfied: click<9.0.0,>=8.1.6 in /usr/local/lib/python3.10/dist-packages (from fitter) (8.1.7)
# Requirement already satisfied: joblib<2.0.0,>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.3.2)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (0.7.2)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (3.8.3)
# Requirement already satisfied: numpy<2.0.0,>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.25.2)
# Requirement already satisfied: pandas<3.0.0,>=0.23.4 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.5.3)
# Requirement already satisfied: rich-click<2.0.0,>=1.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.7.4)
# Requirement already satisfied: scipy<2.0.0,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.11.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.1 in /usr/local/lib/python3.10/dist-packages (from fitter) (4.66.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (24.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.23.4->fitter) (2023.4)
# Requirement already satisfied: rich>=10.7.0 in /usr/local/lib/python3.10/dist-packages (from rich-click<2.0.0,>=1.7.2->fitter) (13.7.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from rich-click<2.0.0,>=1.7.2->fitter) (4.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.2->fitter) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.7.0->rich-click<2.0.0,>=1.7.2->fitter) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.7.0->rich-click<2.0.0,>=1.7.2->fitter) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7.0->rich-click<2.0.0,>=1.7.2->fitter) (0.1.2)

# %%
# to suppress warnings
warnings.filterwarnings('ignore')

# imports the fitter function and produces estimated fits for our residuals
from fitter import Fitter

f = Fitter(tune_residuals)
f.fit()
f.summary
# Out:
# 2024-04-02 13:51:05.181 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED _fit distribution (taking more than 30 seconds)
# 2024-04-02 13:51:05.392 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted alpha distribution with error=0.135068)
# 2024-04-02 13:51:05.411 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted anglit distribution with error=0.079362)
# 2024-04-02 13:51:05.652 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted argus distribution with error=0.012704)
# 2024-04-02 13:51:05.858 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted arcsine distribution with error=0.018445)
# 2024-04-02 13:51:06.723 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted beta distribution with error=0.002741)
# 2024-04-02 13:51:07.055 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted bradford distribution with error=0.01573)
# 2024-04-02 13:51:07.057 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted betaprime distribution with error=0.01339)
# 2024-04-02 13:51:08.391 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted burr12 distribution with error=0.003714)
# 2024-04-02 13:51:08.509 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=0.002445)
# 2024-04-02 13:51:09.492 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi distribution with error=0.020346)
# 2024-04-02 13:51:10.098 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=0.004533)
# 2024-04-02 13:51:10.407 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cosine distribution with error=0.091818)
# 2024-04-02 13:51:12.051 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted burr distribution with error=0.010859)
# 2024-04-02 13:51:12.227 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dgamma distribution with error=0.001334)
# 2024-04-02 13:51:12.698 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dweibull distribution with error=0.001775)
# 2024-04-02 13:51:12.733 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted crystalball distribution with error=0.001243)
# 2024-04-02 13:51:12.763 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=0.018006)
# 2024-04-02 13:51:12.879 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponnorm distribution with error=0.003304)
# 2024-04-02 13:51:13.154 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted erlang distribution with error=0.020072)
# 2024-04-02 13:51:13.723 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=0.021415)
# 2024-04-02 13:51:14.176 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted f distribution with error=0.036822)
# 2024-04-02 13:51:14.222 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponweib distribution with error=0.032713)
# 2024-04-02 13:51:14.564 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted fatiguelife distribution with error=0.003166)
# 2024-04-02 13:51:14.798 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted foldcauchy distribution with error=0.055173)
# 2024-04-02 13:51:14.970 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted foldnorm distribution with error=0.35884)
# 2024-04-02 13:51:15.393 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=0.019451)
# 2024-04-02 13:51:15.514 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted fisk distribution with error=0.031572)
# 2024-04-02 13:51:16.731 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gausshyper distribution with error=134.329701)
# 2024-04-02 13:51:17.728 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genexpon distribution with error=0.017984)
# 2024-04-02 13:51:19.557 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gengamma distribution with error=0.023401)
# 2024-04-02 13:51:19.713 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genextreme distribution with error=0.024782)
# 2024-04-02 13:51:20.154 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genhalflogistic distribution with error=0.015164)
# 2024-04-02 13:51:22.398 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted geninvgauss distribution with error=0.003995)
# 2024-04-02 13:51:22.681 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genlogistic distribution with error=0.001392)
# 2024-04-02 13:51:22.920 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genhyperbolic distribution with error=0.001303)
# 2024-04-02 13:51:22.969 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gennorm distribution with error=0.001999)
# 2024-04-02 13:51:23.350 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gibrat distribution with error=0.017092)
# 2024-04-02 13:51:24.913 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gompertz distribution with error=0.149715)
# 2024-04-02 13:51:24.954 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genpareto distribution with error=0.015789)
# 2024-04-02 13:51:24.999 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gumbel_l distribution with error=0.003819)
# 2024-04-02 13:51:25.006 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gumbel_r distribution with error=0.01085)
# 2024-04-02 13:51:25.235 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfcauchy distribution with error=0.017628)
# 2024-04-02 13:51:25.480 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halflogistic distribution with error=0.017302)
# 2024-04-02 13:51:25.622 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfnorm distribution with error=0.017204)
# 2024-04-02 13:51:25.678 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted hypsecant distribution with error=0.001207)
# 2024-04-02 13:51:25.781 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfgennorm distribution with error=0.020505)
# 2024-04-02 13:51:25.993 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invgamma distribution with error=0.004459)
# 2024-04-02 13:51:26.061 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invgauss distribution with error=0.010228)
# 2024-04-02 13:51:26.381 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invweibull distribution with error=0.01085)
# 2024-04-02 13:51:26.526 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted johnsonsu distribution with error=0.00125)
# 2024-04-02 13:51:26.798 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted kappa3 distribution with error=0.035676)
# 2024-04-02 13:51:27.408 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted johnsonsb distribution with error=0.002599)
# 2024-04-02 13:51:27.554 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted ksone distribution with error=0.015831)
# 2024-04-02 13:51:27.599 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED kstwo distribution (taking more than 30 seconds)
# 2024-04-02 13:51:28.985 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted kstwobign distribution with error=0.746559)
# 2024-04-02 13:51:29.043 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted laplace distribution with error=0.001738)
# 2024-04-02 13:51:29.244 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted laplace_asymmetric distribution with error=0.001569)
# 2024-04-02 13:51:29.475 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy distribution with error=0.017813)
# 2024-04-02 13:51:29.598 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy_l distribution with error=0.015134)
# 2024-04-02 13:51:34.825 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted kappa4 distribution with error=0.015707)
# 2024-04-02 13:51:35.080 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loggamma distribution with error=0.002419)
# 2024-04-02 13:51:35.177 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted logistic distribution with error=0.001184)
# 2024-04-02 13:51:35.611 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loglaplace distribution with error=0.036333)
# 2024-04-02 13:51:36.294 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=0.033282)
# 2024-04-02 13:51:36.671 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED loguniform distribution (taking more than 30 seconds)
# 2024-04-02 13:51:36.894 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lomax distribution with error=0.029588)
# 2024-04-02 13:51:37.313 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted maxwell distribution with error=0.013909)
# 2024-04-02 13:51:38.023 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted mielke distribution with error=0.00117)
# 2024-04-02 13:51:38.096 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted moyal distribution with error=0.002328)
# 2024-04-02 13:51:38.435 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted nakagami distribution with error=0.00333)
# 2024-04-02 13:51:49.099 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy_stable distribution with error=0.001068)
# 2024-04-02 13:51:51.909 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted nct distribution with error=0.001157)
# 2024-04-02 13:51:58.092 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted ncf distribution with error=0.00334)
# 2024-04-02 13:51:58.142 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=0.003304)
# 2024-04-02 13:51:59.079 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norminvgauss distribution with error=0.001475)
# 2024-04-02 13:51:59.125 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted pareto distribution with error=0.018006)
# 2024-04-02 13:51:59.711 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted pearson3 distribution with error=0.001006)
# 2024-04-02 13:51:59.799 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=0.014192)
# 2024-04-02 13:52:02.432 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlognorm distribution with error=0.002527)
# 2024-04-02 13:52:02.547 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted ncx2 distribution with error=0.017909)
# 2024-04-02 13:52:02.569 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=0.01513)
# 2024-04-02 13:52:02.936 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rdist distribution with error=0.064021)
# 2024-04-02 13:52:03.182 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powernorm distribution with error=0.002637)
# 2024-04-02 13:52:03.261 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED reciprocal distribution (taking more than 30 seconds)
# 2024-04-02 13:52:03.677 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rel_breitwigner distribution with error=0.005024)
# 2024-04-02 13:52:04.678 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rice distribution with error=0.38226)
# 2024-04-02 13:52:04.716 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rv_continuous distribution (taking more than 30 seconds)
# 2024-04-02 13:52:04.734 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rv_histogram distribution (taking more than 30 seconds)
# 2024-04-02 13:52:04.980 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted semicircular distribution with error=0.071929)
# 2024-04-02 13:52:05.345 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted skewcauchy distribution with error=0.001952)
# 2024-04-02 13:52:07.275 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted skewnorm distribution with error=0.00278)
# 2024-04-02 13:52:23.581 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted recipinvgauss distribution with error=0.004085)
# 2024-04-02 13:52:27.098 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted t distribution with error=0.001274)
# 2024-04-02 13:52:27.527 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted trapezoid distribution with error=0.013993)
# 2024-04-02 13:52:27.859 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted trapz distribution with error=0.013993)
# 2024-04-02 13:52:28.324 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted triang distribution with error=0.011353)
# 2024-04-02 13:52:28.505 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncexpon distribution with error=0.017017)
# 2024-04-02 13:52:28.728 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncnorm distribution with error=0.003304)
# 2024-04-02 13:52:29.591 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncpareto distribution with error=0.018609)
# 2024-04-02 13:52:30.873 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncweibull_min distribution with error=0.013141)
# 2024-04-02 13:52:31.894 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted tukeylambda distribution with error=0.001705)
# 2024-04-02 13:52:31.948 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=0.01573)
# 2024-04-02 13:52:32.084 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted vonmises distribution with error=2.391504)
# 2024-04-02 13:52:32.139 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED vonmises_fisher distribution (taking more than 30 seconds)
# 2024-04-02 13:52:37.319 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED studentized_range distribution (taking more than 30 seconds)
# 2024-04-02 13:52:37.693 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted wald distribution with error=0.016784)
# 2024-04-02 13:52:38.571 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted weibull_max distribution with error=0.031894)
# 2024-04-02 13:52:39.619 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted weibull_min distribution with error=0.027743)
# 2024-04-02 13:52:39.950 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted wrapcauchy distribution with error=0.020733)
# 2024-04-02 13:52:42.379 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted vonmises_line distribution with error=0.116893)
# <bound method Fitter.summary of <fitter.fitter.Fitter object at 0x7e7336fc2bf0>>

# %% [markdown]
# ## 5. Using Monte Carlo Simulation to Predict Stock Price Intervals
# Now we can generate empirically derived prediction intervals using our chosen distribution (Laplacian), mean (the residuals were centered at zero, so this will just be our predicted stock price), beta (calculated from the residuals as the mean absolute distance from the mean), and number of simulations, which is chosen by the user. We chose to do 1000.

# %%
# creates a function to do MC simulation with a Laplacian distribution
def laplace_monte_carlo(mean, residuals, n_sims):
    # gets the estimated beta or mean absolute distance from the mean
    beta = (sum(abs(residuals - np.mean(residuals)))
                           / len(residuals))
    # uses the numpy function to generate an array of simulated values
    est_range = np.random.laplace(mean, beta, n_sims)
    # converts the array to a list
    est_range = list(est_range)
    # returns the simulated values
    return(est_range)

def roll_forecast_nmc(train, test, std_dev, n_sims):
    # creates a new dataframe that will be added to as the forecast rolls
    history = np.log(train.astype(float))
    # creates an empty list that will hold predictions
    predictions = []
    # loops through the indexes of the set being forecased
    for i in range(len(test)):
        # estimates an ARIMA model of order (1,1,0)
        model = ARIMA(history, order = (1,1,1))
        # fits the model
        model_fit = model.fit()
        # forecasts the next period
        output = model_fit.forecast()
        # takes the predicted value and saves it in yhat
        yhat = np.e ** output[output.index[0]]
        # performs monte carlo simulation using the predicted price as the mean, user-specified
        # standard deviation, and number of simulations
        yhat_range = laplace_monte_carlo(yhat, std_dev, n_sims)
        # appends yhat_range to the list of predictions
        predictions.append([float(i) for i in yhat_range])
        # grabs the observation at the ith index
        obs = test[i : i + 1]
        # appends the observation to the estimation data set
        history = history.append(np.log(obs.astype(float)))

    # converts the predictions list to a pandas dataframe with the same index as the actual
    # values for plotting purposes
    predictions = pd.DataFrame(predictions)
    predictions.index = my_stock_resid_distr_fitting.index
    # converts all the estimated yhats in each column to one list per row
    predictions['predicted_range'] = predictions.values.tolist()
    # grabs only the column with all values in a list
    predictions = pd.DataFrame(predictions['predicted_range'])

    # returns predictions
    return(predictions)

# %%
# attaches the data withheld for investigating the forecast residuals back to the training
# data set to avoid a large error on the first forecast
my_stock_train = my_stock_train.append(my_stock_resid_distr_fitting)


# produces a rolling forecast with prediction intervals using 1000 MC sims
test_preds = roll_forecast_nmc(my_stock_train,
                               my_stock_test,
                               tune_residuals,
                              1000)

# %%
# creates an empty list
in_prediction_interval = []
# loops through the rows in the testing data set
for i in range(len(my_stock_test)):
    # appends true if the actual price is in the interval of predicted prices and false
    # otherwise
    in_prediction_interval.append(np.where(min(test_preds.predicted_range[i]) <=
                                           my_stock_test.close[i]
                                          <= max(test_preds.predicted_range[i]),
                                           True, False))
# prints the percentage of actual prices in the prediction intervals
print('Percentage of Actual Stock Prices in Predicted Stock Price Range: %f' %
      (100 * sum(in_prediction_interval) / len(in_prediction_interval)))
# Out:
# Percentage of Actual Stock Prices in Predicted Stock Price Range: 99.600000

# %% [markdown]
# We plotted the prediction intervals along with the actual stock prices and the actual price does appear to generally be in the middle of our prediction intervals, which is exactly what we want.

# %%
# creates empty lists to append to with minimum and maximum values for each weeks prediction
min_range = []
max_range = []

# loops through the rows in test_preds
for i in range(len(test_preds)):
    # appends to the list the min or max value as appropriate
    min_range.append(min(test_preds.predicted_range[i]))
    max_range.append(max(test_preds.predicted_range[i]))

# converts the lists to data frames and makes their indexes match up with the dates they're
# predicting
min_range = pd.DataFrame(min_range)
min_range.index = my_stock_test.index
max_range = pd.DataFrame(max_range)
max_range.index = my_stock_test.index

# plots the actual stock price with prediction intervals
plt.plot(my_stock_test)
plt.plot(min_range, color = 'yellow')
plt.plot(max_range, color = 'red')
plt.xlabel('Date')
plt.ylabel('Dollars')
plt.title('Actual Closing Weekly Stock Price with Prediction Intervals')
plt.legend(['my_stock_test', 'min_range', 'max_range'])
plt.show()

# %% [markdown]
# ## 6. Conclusions
# So what are potential applications of pairing Monte Carlo simulation and time series modeling in investing? Prediction intervals generated using Monte Carlo simulation can be used to predict the probability that an option is in the money or if a stock is a buy, hold, or sell over a chosen time horizon. We did this below where we calculated the probability that the stock price on 09/12/2019 is greater than or equal to 290 and got the probability of less than 30%.

# %%
# sets a target price to see the probability that the actual stock price is greater than or
# equal to this target
target_price = 290
# creates a list of True values where the simulated price is above or equal to the target price
# and False where it is below
above_target = [i >= target_price for i in test_preds.predicted_range[len(test_preds) - 1]]
# prints the probability
print('Probability Actual Stock Price is above Strike Price: %f' %
      (sum(above_target) / len(above_target)))
# Out:
# Probability Actual Stock Price is above Strike Price: 0.278000
